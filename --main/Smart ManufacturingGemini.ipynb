# %%
import cv2
import numpy as np
from ultralytics import YOLO
import cvzone
import base64
import os
import time
import threading
from openai import OpenAI

# ✅ Set up OpenRouter API Key
client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=""
)

# Load the YOLO model
yolo_model = YOLO("best.pt")
names = yolo_model.names

# Open the video file
cap = cv2.VideoCapture('vid4.mp4')
if not cap.isOpened():
    raise Exception("Error: Could not open video file.")

# Constants for ROI detection and tracking
cx1 = 491
offset = 8

# Get current date for folder and file naming
current_date = time.strftime("%Y-%m-%d")

# Create a folder for cropped images
crop_folder = f"crop_{current_date}"
os.makedirs(crop_folder, exist_ok=True)

# Set to track processed track_ids
processed_track_ids = set()

def encode_image_to_base64(image):
    """Convert an image to a base64 string."""
    _, img_buffer = cv2.imencode('.jpg', image)
    return base64.b64encode(img_buffer).decode('utf-8')

def analyze_image_with_openai(current_image):
    """Analyze a single image using OpenRouter's OpenAI."""
    if current_image is None:
        return "No image available for analysis."

    # Convert image to base64
    current_image_data = encode_image_to_base64(current_image)

    # Create the request
    try:
        response = client.chat.completions.create(
            extra_headers={
                "HTTP-Referer": "<YOUR_SITE_URL>",
                "X-Title": "<YOUR_SITE_NAME>",
            },
            model="google/gemini-2.0-pro-exp-02-05:free",
            messages=[
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": "Analyze this image and determine if the label is present on the bottle. Check the following:\n\n1. **Is the label present?** (Yes/No)\n2. **Is there any damage?** (Yes/No)\n\nReturn the result strictly in a structured table format like below:\n\n| Label Present | Damage |\n|--------------|--------|\n| Yes/No       | Yes/No |"},
                        {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{current_image_data}"}}
                    ]
                }
            ]
        )
        return response.choices[0].message.content
    except Exception as e:
        print(f"Error invoking OpenAI model: {e}")
        return "Error processing image."

def save_response_to_file(track_id, response):
    """Save the analysis response to a text file."""
    timestamp = time.strftime("%Y-%m-%d %H:%M:%S")
    response_filename = f"gemini_response_{current_date}_report.txt"
    
    with open(response_filename, "a", encoding="utf-8") as file:
        file.write(f"Track ID: {track_id} | Condition: {response} | Date: {timestamp}\n\n")

def save_crop_image(crop, track_id):
    """Save cropped image with track ID."""
    timestamp = time.strftime("%Y-%m-%d_%H-%M-%S")
    filename = f"{crop_folder}/{track_id}_{timestamp}.jpg"
    cv2.imwrite(filename, crop)
    return filename

def crop_and_process(frame, box, track_id):
    """Crop detected objects and send for analysis."""
    if track_id in processed_track_ids:
        return  # Skip if already processed

    x1, y1, x2, y2 = box
    crop = frame[y1:y2, x1:x2]

    # Save the cropped image
    crop_filename = save_crop_image(crop, track_id)

    # Mark as processed
    processed_track_ids.add(track_id)

    # Start analysis in a separate thread
    threading.Thread(target=process_crop_image, args=(crop, track_id, crop_filename)).start()

def process_crop_image(current_image, track_id, crop_filename):
    """Process the cropped image and analyze it using OpenAI."""
    response_content = analyze_image_with_openai(current_image)
    print("OpenAI Response:", response_content)
    save_response_to_file(track_id, response_content)
    try:
        with open(response_filename, "w", encoding="utf-8") as f:
            f.write(f"Track ID: {track_id}\nDate: {time.strftime('%Y-%m-%d %H:%M:%S')}\nResponse: {response_content}\n")
    except Exception as e:
        print(f"Error saving response file: {e}")

def process_video_frame(frame):
    """Process video frame for object detection and analysis."""
    frame = cv2.resize(frame, (1020, 500))
    
    # Run YOLOv8 tracking
    results = yolo_model.track(frame, persist=True)
    
    if results[0].boxes is not None:
        boxes = results[0].boxes.xyxy.int().cpu().tolist()
        class_ids = results[0].boxes.cls.int().cpu().tolist()
        track_ids = results[0].boxes.id.int().cpu().tolist() if results[0].boxes.id is not None else [-1] * len(boxes)

        for box, track_id, class_id in zip(boxes, track_ids, class_ids):
            c = names[class_id]
            x1, y1, x2, y2 = box
            cx = int(x1 + x2) // 2

            if cx1 < (cx + offset) and cx1 > (cx - offset):
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cvzone.putTextRect(frame, f'{track_id}', (x2, y2), 1, 1)
                cvzone.putTextRect(frame, f'{c}', (x1, y1), 1, 1)
                crop_and_process(frame, box, track_id)

    return frame

def main():
    """Main function to run video processing."""
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        frame = process_video_frame(frame)

        cv2.line(frame, (491, 1), (491, 499), (0, 0, 255), 2)
        cv2.imshow("RGB", frame)
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break

    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
# Out:
# 0: 320x640 1 product, 24.2ms
# Speed: 2.1ms preprocess, 24.2ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 19.2ms
# Speed: 2.0ms preprocess, 19.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 18.6ms
# Speed: 2.0ms preprocess, 18.6ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 20.1ms
# Speed: 1.0ms preprocess, 20.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 19.5ms
# Speed: 1.0ms preprocess, 19.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 25.2ms
# Speed: 1.0ms preprocess, 25.2ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 18.4ms
# Speed: 1.0ms preprocess, 18.4ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 19.8ms
# Speed: 1.0ms preprocess, 19.8ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.5ms
# Speed: 2.0ms preprocess, 17.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 22.6ms
# Speed: 1.0ms preprocess, 22.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.7ms
# Speed: 1.0ms preprocess, 17.7ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 18.2ms
# Speed: 1.0ms preprocess, 18.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 17.4ms
# Speed: 1.0ms preprocess, 17.4ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 17.6ms
# Speed: 1.0ms preprocess, 17.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 19.0ms
# Speed: 2.0ms preprocess, 19.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 20.3ms
# Speed: 2.0ms preprocess, 20.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 21.5ms
# Speed: 2.3ms preprocess, 21.5ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 26.2ms
# Speed: 2.0ms preprocess, 26.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 17.3ms
# Speed: 1.0ms preprocess, 17.3ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 17.5ms
# Speed: 2.0ms preprocess, 17.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 21.4ms
# Speed: 1.0ms preprocess, 21.4ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 18.2ms
# Speed: 1.0ms preprocess, 18.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 19.5ms
# Speed: 1.3ms preprocess, 19.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 18.4ms
# Speed: 1.0ms preprocess, 18.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 20.4ms
# Speed: 2.0ms preprocess, 20.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 19.1ms
# Speed: 2.0ms preprocess, 19.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 19.7ms
# Speed: 1.0ms preprocess, 19.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 19.1ms
# Speed: 3.0ms preprocess, 19.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 18.5ms
# Speed: 1.4ms preprocess, 18.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 19.2ms
# Speed: 1.2ms preprocess, 19.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 24.3ms
# Speed: 1.0ms preprocess, 24.3ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 19.4ms
# Speed: 1.0ms preprocess, 19.4ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 30.6ms
# Speed: 2.0ms preprocess, 30.6ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 23.2ms
# Speed: 1.0ms preprocess, 23.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 20.2ms
# Speed: 1.0ms preprocess, 20.2ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 20.0ms
# Speed: 1.0ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 20.1ms
# Speed: 1.0ms preprocess, 20.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 19.3ms
# Speed: 3.0ms preprocess, 19.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 19.8ms
# Speed: 2.0ms preprocess, 19.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 20.3ms
# Speed: 2.0ms preprocess, 20.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 19.6ms
# Speed: 1.0ms preprocess, 19.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 19.7ms
# Speed: 1.0ms preprocess, 19.7ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 19.4ms
# Speed: 2.0ms preprocess, 19.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 19.7ms
# Speed: 1.0ms preprocess, 19.7ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 20.3ms
# Speed: 1.0ms preprocess, 20.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 20.3ms
# Speed: 1.0ms preprocess, 20.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 22.4ms
# Speed: 1.9ms preprocess, 22.4ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 18.5ms
# Speed: 1.0ms preprocess, 18.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.9ms
# Speed: 2.0ms preprocess, 17.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 18.0ms
# Speed: 2.4ms preprocess, 18.0ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 18.7ms
# Speed: 1.0ms preprocess, 18.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 23.2ms
# Speed: 2.0ms preprocess, 23.2ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 22.6ms
# Speed: 2.1ms preprocess, 22.6ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 26.6ms
# Speed: 2.0ms preprocess, 26.6ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 23.1ms
# Speed: 2.0ms preprocess, 23.1ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 18.9ms
# Speed: 1.0ms preprocess, 18.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 18.1ms
# Speed: 1.0ms preprocess, 18.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 18.9ms
# Speed: 1.0ms preprocess, 18.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 18.3ms
# Speed: 1.0ms preprocess, 18.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 18.3ms
# Speed: 2.0ms preprocess, 18.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 18.1ms
# Speed: 1.0ms preprocess, 18.1ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.4ms
# Speed: 1.0ms preprocess, 17.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.4ms
# Speed: 2.0ms preprocess, 17.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 18.7ms
# Speed: 0.0ms preprocess, 18.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.4ms
# Speed: 1.0ms preprocess, 17.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.5ms
# Speed: 2.2ms preprocess, 17.5ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.2ms
# Speed: 1.0ms preprocess, 17.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.7ms
# Speed: 2.0ms preprocess, 17.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.4ms
# Speed: 1.0ms preprocess, 17.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.4ms
# Speed: 1.0ms preprocess, 17.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 27.6ms
# Speed: 1.0ms preprocess, 27.6ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 640)
#
# OpenAI Response: Here's the analysis of the image in the requested table format:
#
# | Label Present | Damage |
# |--------------|--------|
# | Yes           | No     |
#
# Error saving response file: name 'response_filename' is not defined
# 0: 320x640 1 product, 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.5ms
# Speed: 1.0ms preprocess, 17.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.6ms
# Speed: 1.0ms preprocess, 17.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.7ms
# Speed: 1.0ms preprocess, 17.7ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 20.6ms
# Speed: 1.0ms preprocess, 20.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 19.7ms
# Speed: 1.0ms preprocess, 19.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.4ms
# Speed: 1.0ms preprocess, 17.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.9ms
# Speed: 2.0ms preprocess, 17.9ms inference, 5.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.4ms
# Speed: 2.0ms preprocess, 17.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 20.0ms
# Speed: 1.0ms preprocess, 20.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 17.6ms
# Speed: 1.0ms preprocess, 17.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 16.2ms
# Speed: 2.2ms preprocess, 16.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 17.3ms
# Speed: 1.0ms preprocess, 17.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 16.3ms
# Speed: 2.3ms preprocess, 16.3ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 16.4ms
# Speed: 1.0ms preprocess, 16.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# OpenAI Response: Here's the analysis of the image in the requested table format:
#
# | Label Present | Damage |
# |--------------|--------|
# | Yes          | No     |
#
# Error saving response file: name 'response_filename' is not defined
# 0: 320x640 2 products, 17.6ms
# Speed: 1.0ms preprocess, 17.6ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 16.2ms
# Speed: 2.3ms preprocess, 16.2ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 16.7ms
# Speed: 1.0ms preprocess, 16.7ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 16.9ms
# Speed: 2.0ms preprocess, 16.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 17.2ms
# Speed: 1.2ms preprocess, 17.2ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 17.3ms
# Speed: 1.0ms preprocess, 17.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 16.2ms
# Speed: 2.4ms preprocess, 16.2ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 17.4ms
# Speed: 1.0ms preprocess, 17.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 16.6ms
# Speed: 1.0ms preprocess, 16.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.4ms
# Speed: 2.0ms preprocess, 17.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.4ms
# Speed: 1.0ms preprocess, 17.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 18.3ms
# Speed: 1.0ms preprocess, 18.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 16.2ms
# Speed: 2.5ms preprocess, 16.2ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.2ms
# Speed: 1.0ms preprocess, 17.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.3ms
# Speed: 1.0ms preprocess, 17.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.0ms
# Speed: 1.2ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.2ms
# Speed: 2.3ms preprocess, 17.2ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 15.4ms
# Speed: 2.0ms preprocess, 15.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 16.4ms
# Speed: 1.0ms preprocess, 16.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 16.5ms
# Speed: 1.0ms preprocess, 16.5ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 16.8ms
# Speed: 1.0ms preprocess, 16.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 16.7ms
# Speed: 1.0ms preprocess, 16.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 16.7ms
# Speed: 1.0ms preprocess, 16.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 16.3ms
# Speed: 2.3ms preprocess, 16.3ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 16.5ms
# Speed: 1.2ms preprocess, 16.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 16.0ms
# Speed: 2.2ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 23.4ms
# Speed: 1.0ms preprocess, 23.4ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# OpenAI Response: Here's the analysis of the image in the requested table format:
#
# | Label Present | Damage |
# |--------------|--------|
# | Yes          | No     |
#
# Error saving response file: name 'response_filename' is not defined
# 0: 320x640 2 products, 16.4ms
# Speed: 6.0ms preprocess, 16.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 16.4ms
# Speed: 1.0ms preprocess, 16.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 17.2ms
# Speed: 1.0ms preprocess, 17.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 16.2ms
# Speed: 2.3ms preprocess, 16.2ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.2ms
# Speed: 1.0ms preprocess, 17.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 16.3ms
# Speed: 1.0ms preprocess, 16.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 24.9ms
# Speed: 2.3ms preprocess, 24.9ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 16.5ms
# Speed: 2.5ms preprocess, 16.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 16.5ms
# Speed: 2.2ms preprocess, 16.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 18.0ms
# Speed: 2.2ms preprocess, 18.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.3ms
# Speed: 1.0ms preprocess, 17.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.6ms
# Speed: 1.0ms preprocess, 17.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.4ms
# Speed: 1.0ms preprocess, 17.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.3ms
# Speed: 1.0ms preprocess, 17.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 22.2ms
# Speed: 2.2ms preprocess, 22.2ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 18.2ms
# Speed: 1.0ms preprocess, 18.2ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.3ms
# Speed: 2.3ms preprocess, 17.3ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.4ms
# Speed: 1.0ms preprocess, 17.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.3ms
# Speed: 2.2ms preprocess, 17.3ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 18.3ms
# Speed: 1.0ms preprocess, 18.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 18.2ms
# Speed: 1.0ms preprocess, 18.2ms inference, 4.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 18.4ms
# Speed: 1.0ms preprocess, 18.4ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 17.4ms
# Speed: 2.0ms preprocess, 17.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 17.5ms
# Speed: 2.0ms preprocess, 17.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 18.3ms
# Speed: 1.0ms preprocess, 18.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
# OpenAI Response: Here's the analysis of the image in the requested table format:
#
# | Label Present | Damage |
# |--------------|--------|
# | No            | No     |
#
# Error saving response file: name 'response_filename' is not defined
#
# 0: 320x640 2 products, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 19.0ms
# Speed: 2.0ms preprocess, 19.0ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 18.3ms
# Speed: 2.0ms preprocess, 18.3ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 18.4ms
# Speed: 2.0ms preprocess, 18.4ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 18.3ms
# Speed: 1.0ms preprocess, 18.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 18.5ms
# Speed: 2.0ms preprocess, 18.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 19.4ms
# Speed: 1.0ms preprocess, 19.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 18.4ms
# Speed: 1.0ms preprocess, 18.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 19.5ms
# Speed: 2.0ms preprocess, 19.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 19.3ms
# Speed: 1.0ms preprocess, 19.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 18.5ms
# Speed: 2.0ms preprocess, 18.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 18.2ms
# Speed: 2.4ms preprocess, 18.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 18.9ms
# Speed: 2.4ms preprocess, 18.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 18.5ms
# Speed: 3.0ms preprocess, 18.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 18.3ms
# Speed: 1.2ms preprocess, 18.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# OpenAI Response: Here's the analysis of the image in the requested table format:
#
# | Label Present | Damage |
# |--------------|--------|
# | Yes          | No     |
#
# Error saving response file: name 'response_filename' is not defined

# %%
import cv2
import numpy as np
from ultralytics import YOLO
import cvzone
import base64
import os
import time
import threading
from openai import OpenAI

# ✅ Set up OpenRouter API Key
client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=""
)

# Load the YOLO model
yolo_model = YOLO("best.pt")
names = yolo_model.names

# Open the video file
cap = cv2.VideoCapture('vid4.mp4')
if not cap.isOpened():
    raise Exception("Error: Could not open video file.")

# Constants for ROI detection and tracking
cx1 = 491
offset = 8

# Get current date for folder and file naming
current_date = time.strftime("%Y-%m-%d")

# Create a folder for cropped images
crop_folder = f"crop_{current_date}"
os.makedirs(crop_folder, exist_ok=True)

# Set to track processed track_ids
processed_track_ids = set()

def encode_image_to_base64(image):
    """Convert an image to a base64 string."""
    _, img_buffer = cv2.imencode('.jpg', image)
    return base64.b64encode(img_buffer).decode('utf-8')

def analyze_image_with_openai(current_image):
    """Analyze a single image using OpenRouter's OpenAI."""
    if current_image is None:
        return "No image available for analysis."

    # Convert image to base64
    current_image_data = encode_image_to_base64(current_image)

    # Create the request
    try:
        response = client.chat.completions.create(
            extra_headers={
                "HTTP-Referer": "<YOUR_SITE_URL>",
                "X-Title": "<YOUR_SITE_NAME>",
            },
            model="google/gemini-2.0-pro-exp-02-05:free",
            messages=[{
                    "role": "user",
                    "content": [
                        {
                          "type": "text",
                          "text": "Analyze this image and determine if the label is present on the bottle. Check the following:\n\n"
                                  "1. **Is the label present?** (Yes/No)\n"
                                  "2. **Is there any damage?** (Yes/No)\n\n"
                                  "Return the result strictly in a structured table format like below:\n\n"
                                  "| Label Present | Damage |\n"
                                  "|--------------|--------|\n"
                                  "| Yes/No       | Yes/No |"
                        },
                        {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{current_image_data}"}}
                    ]
                }
            ]
        )
        return response.choices[0].message.content
    except Exception as e:
        print(f"Error invoking OpenAI model: {e}")
        return "Error processing image."

def save_response_to_file(track_id, response, crop_filename):
    """Save the analysis response to a separate .txt file for each bottle."""
    timestamp = time.strftime("%Y-%m-%d %H:%M:%S")
    
    # Extract the base filename from the cropped image
    txt_filename = crop_filename.replace(".jpg", ".txt")
    
    # Create the file and save the structured response
    with open(txt_filename, "w", encoding="utf-8") as file:
        file.write(f"Track ID: {track_id}\n")
        file.write(f"Date: {timestamp}\n")
        file.write(f"{response}\n")

def save_crop_image(crop, track_id):
    """Save cropped image with track ID."""
    timestamp = time.strftime("%Y-%m-%d_%H-%M-%S")
    filename = f"{crop_folder}/{track_id}_{timestamp}.jpg"
    cv2.imwrite(filename, crop)
    return filename

def crop_and_process(frame, box, track_id):
    """Crop detected objects and send for analysis."""
    if track_id in processed_track_ids:
        return  # Skip if already processed

    x1, y1, x2, y2 = box
    crop = frame[y1:y2, x1:x2]

    # Save the cropped image
    crop_filename = save_crop_image(crop, track_id)

    # Mark as processed
    processed_track_ids.add(track_id)

    # Start analysis in a separate thread
    threading.Thread(target=process_crop_image, args=(crop, track_id, crop_filename)).start()

def process_crop_image(current_image, track_id, crop_filename):
    """Process the cropped image and analyze it using OpenAI."""
    response_content = analyze_image_with_openai(current_image)
    print(f"OpenAI Response for Track ID {track_id}:", response_content)
    
    # Save response in a separate .txt file for each bottle
    save_response_to_file(track_id, response_content, crop_filename)

def process_video_frame(frame):
    """Process video frame for object detection and analysis."""
    frame = cv2.resize(frame, (1020, 500))
    
    # Run YOLOv8 tracking
    results = yolo_model.track(frame, persist=True)
    
    if results[0].boxes is not None:
        boxes = results[0].boxes.xyxy.int().cpu().tolist()
        class_ids = results[0].boxes.cls.int().cpu().tolist()
        track_ids = results[0].boxes.id.int().cpu().tolist() if results[0].boxes.id is not None else [-1] * len(boxes)

        for box, track_id, class_id in zip(boxes, track_ids, class_ids):
            c = names[class_id]
            x1, y1, x2, y2 = box
            cx = int(x1 + x2) // 2

            if cx1 < (cx + offset) and cx1 > (cx - offset):
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cvzone.putTextRect(frame, f'{track_id}', (x2, y2), 1, 1)
                cvzone.putTextRect(frame, f'{c}', (x1, y1), 1, 1)
                crop_and_process(frame, box, track_id)

    return frame

def main():
    """Main function to run video processing."""
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        frame = process_video_frame(frame)

        cv2.line(frame, (491, 1), (491, 499), (0, 0, 255), 2)
        cv2.imshow("RGB", frame)
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break

    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
# Out:
# 0: 320x640 1 product, 45.1ms
# Speed: 4.0ms preprocess, 45.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 29.6ms
# Speed: 2.0ms preprocess, 29.6ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 26.0ms
# Speed: 2.5ms preprocess, 26.0ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 23.6ms
# Speed: 4.2ms preprocess, 23.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 23.4ms
# Speed: 1.0ms preprocess, 23.4ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 24.1ms
# Speed: 4.5ms preprocess, 24.1ms inference, 6.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 31.6ms
# Speed: 4.0ms preprocess, 31.6ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 22.1ms
# Speed: 3.0ms preprocess, 22.1ms inference, 4.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 22.1ms
# Speed: 3.0ms preprocess, 22.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 20.9ms
# Speed: 2.0ms preprocess, 20.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 19.9ms
# Speed: 3.0ms preprocess, 19.9ms inference, 6.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 25.1ms
# Speed: 4.6ms preprocess, 25.1ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 27.8ms
# Speed: 2.0ms preprocess, 27.8ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 24.2ms
# Speed: 1.5ms preprocess, 24.2ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 22.8ms
# Speed: 3.0ms preprocess, 22.8ms inference, 6.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 19.6ms
# Speed: 2.0ms preprocess, 19.6ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 23.5ms
# Speed: 1.0ms preprocess, 23.5ms inference, 5.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 19.1ms
# Speed: 3.1ms preprocess, 19.1ms inference, 5.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 43.8ms
# Speed: 2.0ms preprocess, 43.8ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 23.1ms
# Speed: 2.0ms preprocess, 23.1ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 30.0ms
# Speed: 2.0ms preprocess, 30.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 23.2ms
# Speed: 1.0ms preprocess, 23.2ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 27.7ms
# Speed: 3.0ms preprocess, 27.7ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 21.6ms
# Speed: 2.5ms preprocess, 21.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 23.1ms
# Speed: 2.0ms preprocess, 23.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 21.8ms
# Speed: 2.0ms preprocess, 21.8ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 25.1ms
# Speed: 2.0ms preprocess, 25.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 29.2ms
# Speed: 4.5ms preprocess, 29.2ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 21.0ms
# Speed: 2.0ms preprocess, 21.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 24.2ms
# Speed: 2.0ms preprocess, 24.2ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 23.2ms
# Speed: 1.0ms preprocess, 23.2ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 26.6ms
# Speed: 4.6ms preprocess, 26.6ms inference, 7.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 29.7ms
# Speed: 2.0ms preprocess, 29.7ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 23.1ms
# Speed: 2.0ms preprocess, 23.1ms inference, 6.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 25.3ms
# Speed: 3.0ms preprocess, 25.3ms inference, 7.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 23.1ms
# Speed: 1.0ms preprocess, 23.1ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 32.6ms
# Speed: 1.0ms preprocess, 32.6ms inference, 5.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 24.0ms
# Speed: 3.0ms preprocess, 24.0ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 23.3ms
# Speed: 1.5ms preprocess, 23.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 23.1ms
# Speed: 2.5ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 30.6ms
# Speed: 1.0ms preprocess, 30.6ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 23.7ms
# Speed: 1.0ms preprocess, 23.7ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 23.1ms
# Speed: 1.0ms preprocess, 23.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 22.6ms
# Speed: 2.0ms preprocess, 22.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 23.6ms
# Speed: 1.0ms preprocess, 23.6ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 22.5ms
# Speed: 1.0ms preprocess, 22.5ms inference, 4.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 23.1ms
# Speed: 2.0ms preprocess, 23.1ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 26.6ms
# Speed: 3.0ms preprocess, 26.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 23.1ms
# Speed: 2.0ms preprocess, 23.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 22.1ms
# Speed: 2.0ms preprocess, 22.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# OpenAI Response for Track ID 1: Here's the analysis of the image in the requested table format:
#
# | Label Present | Damage |
# |--------------|--------|
# | Yes          | No     |
#
# 0: 320x640 1 product, 35.4ms
# Speed: 1.0ms preprocess, 35.4ms inference, 4.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 28.6ms
# Speed: 2.0ms preprocess, 28.6ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 23.4ms
# Speed: 2.0ms preprocess, 23.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 23.6ms
# Speed: 2.2ms preprocess, 23.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 26.0ms
# Speed: 3.0ms preprocess, 26.0ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 25.1ms
# Speed: 2.0ms preprocess, 25.1ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 22.7ms
# Speed: 2.0ms preprocess, 22.7ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 29.7ms
# Speed: 1.0ms preprocess, 29.7ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 31.1ms
# Speed: 2.0ms preprocess, 31.1ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 23.6ms
# Speed: 3.0ms preprocess, 23.6ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 23.1ms
# Speed: 1.0ms preprocess, 23.1ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 23.9ms
# Speed: 1.0ms preprocess, 23.9ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 21.1ms
# Speed: 3.0ms preprocess, 21.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 25.6ms
# Speed: 1.0ms preprocess, 25.6ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 8.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 28.6ms
# Speed: 2.0ms preprocess, 28.6ms inference, 7.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 25.9ms
# Speed: 2.0ms preprocess, 25.9ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 23.0ms
# Speed: 2.0ms preprocess, 23.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 21.8ms
# Speed: 2.0ms preprocess, 21.8ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 21.0ms
# Speed: 2.0ms preprocess, 21.0ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 23.9ms
# Speed: 1.0ms preprocess, 23.9ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 26.1ms
# Speed: 2.0ms preprocess, 26.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 23.7ms
# Speed: 2.0ms preprocess, 23.7ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 24.6ms
# Speed: 1.0ms preprocess, 24.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 29.5ms
# Speed: 2.0ms preprocess, 29.5ms inference, 6.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 26.6ms
# Speed: 2.0ms preprocess, 26.6ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 20.1ms
# Speed: 2.0ms preprocess, 20.1ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 19.8ms
# Speed: 3.0ms preprocess, 19.8ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# OpenAI Response for Track ID 2: Here's the analysis in the requested table format:
#
# | Label Present | Damage |
# |--------------|--------|
# | Yes       | No |
#
# 0: 320x640 1 product, 25.9ms
# Speed: 2.5ms preprocess, 25.9ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 21.5ms
# Speed: 2.0ms preprocess, 21.5ms inference, 6.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 21.8ms
# Speed: 2.0ms preprocess, 21.8ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 22.3ms
# Speed: 2.0ms preprocess, 22.3ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 21.0ms
# Speed: 1.5ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 28.4ms
# Speed: 3.0ms preprocess, 28.4ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 21.5ms
# Speed: 1.0ms preprocess, 21.5ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 22.9ms
# Speed: 2.0ms preprocess, 22.9ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 22.5ms
# Speed: 2.0ms preprocess, 22.5ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 21.1ms
# Speed: 2.0ms preprocess, 21.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 22.4ms
# Speed: 1.0ms preprocess, 22.4ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 20.6ms
# Speed: 2.0ms preprocess, 20.6ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 20.6ms
# Speed: 1.0ms preprocess, 20.6ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 20.1ms
# Speed: 1.0ms preprocess, 20.1ms inference, 6.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 19.9ms
# Speed: 2.0ms preprocess, 19.9ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 4.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 22.1ms
# Speed: 2.0ms preprocess, 22.1ms inference, 5.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 21.9ms
# Speed: 1.0ms preprocess, 21.9ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 20.9ms
# Speed: 2.0ms preprocess, 20.9ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 23.1ms
# Speed: 1.0ms preprocess, 23.1ms inference, 5.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 28.0ms
# Speed: 4.8ms preprocess, 28.0ms inference, 5.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 21.1ms
# Speed: 2.0ms preprocess, 21.1ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 23.5ms
# Speed: 1.0ms preprocess, 23.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 20.7ms
# Speed: 2.0ms preprocess, 20.7ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 19.8ms
# Speed: 1.0ms preprocess, 19.8ms inference, 5.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 21.1ms
# Speed: 2.0ms preprocess, 21.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 25.1ms
# Speed: 1.0ms preprocess, 25.1ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 27.1ms
# Speed: 2.0ms preprocess, 27.1ms inference, 6.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 22.4ms
# Speed: 2.0ms preprocess, 22.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 21.6ms
# Speed: 3.0ms preprocess, 21.6ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 24.1ms
# Speed: 3.0ms preprocess, 24.1ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 29.8ms
# Speed: 4.0ms preprocess, 29.8ms inference, 4.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 33.6ms
# Speed: 2.0ms preprocess, 33.6ms inference, 6.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 24.3ms
# Speed: 1.0ms preprocess, 24.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 19.1ms
# Speed: 2.0ms preprocess, 19.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 22.1ms
# Speed: 2.0ms preprocess, 22.1ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 20.4ms
# Speed: 2.0ms preprocess, 20.4ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 22.6ms
# Speed: 3.0ms preprocess, 22.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 20.1ms
# Speed: 2.5ms preprocess, 20.1ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# OpenAI Response for Track ID 3: Here's the analysis of the image in the requested table format:
#
# | Label Present | Damage |
# |--------------|--------|
# | Yes          | No     |
#
# 0: 320x640 1 product, 29.2ms
# Speed: 2.0ms preprocess, 29.2ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 25.0ms
# Speed: 3.0ms preprocess, 25.0ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 20.0ms
# Speed: 2.1ms preprocess, 20.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 20.9ms
# Speed: 2.0ms preprocess, 20.9ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 21.1ms
# Speed: 3.0ms preprocess, 21.1ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 29.0ms
# Speed: 2.0ms preprocess, 29.0ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 30.8ms
# Speed: 4.0ms preprocess, 30.8ms inference, 5.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 22.1ms
# Speed: 2.0ms preprocess, 22.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 23.0ms
# Speed: 2.0ms preprocess, 23.0ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 23.1ms
# Speed: 2.0ms preprocess, 23.1ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 22.6ms
# Speed: 2.5ms preprocess, 22.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 21.0ms
# Speed: 3.4ms preprocess, 21.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 24.1ms
# Speed: 3.1ms preprocess, 24.1ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 29.2ms
# Speed: 3.0ms preprocess, 29.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 23.0ms
# Speed: 2.0ms preprocess, 23.0ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 31.8ms
# Speed: 1.0ms preprocess, 31.8ms inference, 5.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 25.0ms
# Speed: 2.6ms preprocess, 25.0ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 21.3ms
# Speed: 1.0ms preprocess, 21.3ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 25.6ms
# Speed: 4.0ms preprocess, 25.6ms inference, 5.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 20.1ms
# Speed: 2.0ms preprocess, 20.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 20.0ms
# Speed: 3.0ms preprocess, 20.0ms inference, 4.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 20.1ms
# Speed: 2.5ms preprocess, 20.1ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 20.1ms
# Speed: 2.0ms preprocess, 20.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 20.5ms
# Speed: 2.4ms preprocess, 20.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 22.9ms
# Speed: 4.5ms preprocess, 22.9ms inference, 5.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 20.5ms
# Speed: 3.0ms preprocess, 20.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 20.6ms
# Speed: 2.0ms preprocess, 20.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 20.9ms
# Speed: 1.0ms preprocess, 20.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 21.1ms
# Speed: 2.0ms preprocess, 21.1ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 20.1ms
# Speed: 2.5ms preprocess, 20.1ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 25.1ms
# Speed: 3.0ms preprocess, 25.1ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 29.7ms
# Speed: 3.0ms preprocess, 29.7ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 37.2ms
# Speed: 3.0ms preprocess, 37.2ms inference, 5.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 20.7ms
# Speed: 1.0ms preprocess, 20.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# OpenAI Response for Track ID 4: Here's the analysis of the image in the requested table format:
#
# | Label Present | Damage |
# |--------------|--------|
# | No           | No     |
#
# 0: 320x640 1 product, 30.0ms
# Speed: 3.0ms preprocess, 30.0ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 19.8ms
# Speed: 2.0ms preprocess, 19.8ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 22.6ms
# Speed: 2.0ms preprocess, 22.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 19.9ms
# Speed: 2.0ms preprocess, 19.9ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 28.3ms
# Speed: 1.0ms preprocess, 28.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 27.0ms
# Speed: 3.0ms preprocess, 27.0ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 29.6ms
# Speed: 2.5ms preprocess, 29.6ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 21.0ms
# Speed: 2.0ms preprocess, 21.0ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 22.6ms
# Speed: 1.0ms preprocess, 22.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 28.7ms
# Speed: 3.0ms preprocess, 28.7ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 23.6ms
# Speed: 2.0ms preprocess, 23.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 31.1ms
# Speed: 3.0ms preprocess, 31.1ms inference, 6.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 22.1ms
# Speed: 1.5ms preprocess, 22.1ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 23.1ms
# Speed: 3.5ms preprocess, 23.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 22.5ms
# Speed: 4.0ms preprocess, 22.5ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 27.6ms
# Speed: 2.0ms preprocess, 27.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 24.2ms
# Speed: 3.0ms preprocess, 24.2ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 21.6ms
# Speed: 3.0ms preprocess, 21.6ms inference, 4.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 22.7ms
# Speed: 2.0ms preprocess, 22.7ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 24.5ms
# Speed: 2.5ms preprocess, 24.5ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 22.5ms
# Speed: 2.0ms preprocess, 22.5ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 21.6ms
# Speed: 2.0ms preprocess, 21.6ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 21.0ms
# Speed: 2.0ms preprocess, 21.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 31.6ms
# Speed: 1.4ms preprocess, 31.6ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 20.9ms
# Speed: 2.0ms preprocess, 20.9ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 21.0ms
# Speed: 1.4ms preprocess, 21.0ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 25.6ms
# Speed: 3.3ms preprocess, 25.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 24.6ms
# Speed: 3.0ms preprocess, 24.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 24.4ms
# Speed: 2.0ms preprocess, 24.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 22.9ms
# Speed: 1.0ms preprocess, 22.9ms inference, 5.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 20.8ms
# Speed: 2.0ms preprocess, 20.8ms inference, 4.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 21.6ms
# Speed: 2.0ms preprocess, 21.6ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 28.4ms
# Speed: 2.0ms preprocess, 28.4ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 26.1ms
# Speed: 2.0ms preprocess, 26.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 products, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 21.5ms
# Speed: 2.0ms preprocess, 21.5ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 product, 32.0ms
# Speed: 2.4ms preprocess, 32.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
# OpenAI Response for Track ID 5: Here's the analysis of the image in the requested table format:
#
# | Label Present | Damage |
# |--------------|--------|
# | Yes          | No     |
